# %% [markdown]
# # Tarefa 03
#
# - Leia os enunciados com atenção
# - Saiba que pode haver mais de uma resposta correta
# - Insira novas células de código sempre que achar necessário
# - Em caso de dúvidas, procure os Tutores
# - Divirta-se :)

# %%
import pandas as pd
import requests

# %% [markdown]
# ####  1) Lendo de APIs
# Vimos em aula como carregar dados públicos do governo através de um API (*Application Programming Interface*). No exemplo de aula, baixamos os dados de pedidos de verificação de limites (PVL) realizados por estados, e selecionamos apenas aqueles referentes ao estado de São Paulo.
#
# 1. Repita os mesmos passos feitos em aula, mas selecione os PVLs realizados por municípios no estado do Rio de Janeiro.
# 2. Quais são os três *status* das solicitações mais frequentes na base? Quais são suas frequências?
# 3. Construa uma nova variável que contenha o ano do **status**. Observe que ```data_status``` vem como tipo *object* no **DataFrame**. Dica: você pode usar o método ```.str``` para transformar o tipo da variável em string, em seguida um método como [**slice()**](https://pandas.pydata.org/docs/reference/api/pandas.Series.str.slice.html) ou [**split()**](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.Series.str.split.html).
# 4. Indique a frequência de cada ano do campo construído no item (3).

# %%
# 1) Seu código aqui
url = 'https://apidatalake.tesouro.gov.br/ords/sadipem/tt/pvl'

r = requests.get(url)

r.status_code
# Out:
# 200

# %%
data = r.json()

# %%
print(data['items'])
# Out:
# [{'id_pleito': 63735, 'tipo_interessado': 'Município', 'interessado': 'Forquilha', 'cod_ibge': 2304350, 'uf': 'CE', 'num_pvl': 'PVL02.000825/2023-17', 'status': 'Deferido (PVL-IF)', 'num_processo': None, 'data_protocolo': None, 'tipo_operacao': 'Operação contratual interna', 'finalidade': 'Infraestrutura', 'tipo_credor': 'Instituição Financeira Nacional', 'credor': 'Banco do Brasil S/A', 'moeda': 'Real', 'valor': 1971000, 'pvl_assoc_divida': 0, 'pvl_contradado_credor': 1, 'data_status': '29/05/2023'}, {'id_pleito': 65995, 'tipo_interessado': 'Município', 'interessado': 'Maceió', 'cod_ibge': 2704302, 'uf': 'AL', 'num_pvl': 'PVL02.000568/2023-13', 'status': 'Em retificação pelo interessado', 'num_processo': '17944.103616/2023-89', 'data_protocolo': '2023-07-27T16:11:14Z', 'tipo_operacao': 'Operação contratual interna', 'finalidade': 'PNAFM', 'tipo_credor': 'Instituição Financeira Nacional', 'credor': 'Caixa Econômica Federal', 'moeda': 'Real', 'valor': 25000000, 'pvl_assoc_divida': 0, 'pvl_contradado_credor': 0, 'data_status': '03/08/2023'}, {'id_pleito': 66665, 'tipo_interessado': 'Município', 'interessado': 'Campinas', 'cod_ibge': 3509502, 'uf': 'SP', 'num_pvl': 'PVL02.002498/2023-20', 'status': 'Em retificação pelo interessado', 'num_processo': '17944.104410/2023-76', 'data_protocolo': '2023-09-12T18:27:55Z', 'tipo_operacao': 'Operação contratual interna (com garantia da União)', 'finalidade': 'PMAT', 'tipo_credor': 'Instituição Financeira Nacional', 'credor': 'Banco Nacional de Desenvolvimento Econômico e Social', 'moeda': 'Real', 'valor': 65838603, 'pvl_assoc_divida': 0, 'pvl_contradado_credor': 0, 'data_status': '16/11/2023'}, {'id_pleito': 65370, 'tipo_interessado': 'Município', 'interessado': 'Santana da Boa Vista', 'cod_ibge': 4317004, 'uf': 'RS', 'num_pvl': 'PVL02.002462/2023-46', 'status': 'Em retificação pelo interessado (PVL-IF)', 'num_processo': None, 'data_protocolo': None, 'tipo_operacao': 'Operação contratual interna', 'finalidade': 'Infraestrutura', 'tipo_credor': 'Instituição Financeira Nacional', 'credor': 'Caixa Econômica Federal', 'moeda': 'Real', 'valor': 10000000, 'pvl_assoc_divida': 0, 'pvl_contradado_credor': 0, 'data_status': '13/11/2023'}, {'id_pleito': 51271, 'tipo_interessado': 'Município', 'interessado': 'Dois Vizinhos', 'cod_ibge': 4107207, 'uf': 'PR', 'num_pvl': 'PVL02.001479/2021-14', 'status': 'Deferido', 'num_processo': '17944.104586/2021-66', 'data_protocolo': '2021-12-17T12:37:23Z', 'tipo_operacao': 'Operação contratual interna', 'finalidade': 'Multissetorial', 'tipo_credor': 'Instituição Financeira Nacional', 'credor': 'Agência de Fomento do Paraná S/A', 'moeda': 'Real', 'valor': 13000000, 'pvl_assoc_divida': 0, 'pvl_contradado_credor': 1, 'data_status': '29/12/2021'}, {'id_pleito': 60064, 'tipo_interessado': 'Município', 'interessado': 'Porto Alegre', 'cod_ibge': 4314902, 'uf': 'RS', 'num_pvl': 'PVL02.002822/2021-48', 'status': 'Encaminhado à PGFN com manifestação técnica favorável', 'num_processo': '17944.102427/2022-16', 'data_protocolo': '2022-09-06T13:13:34Z', 'tipo_operacao': 'Operação contratual interna (com garantia da União)', 'finalidade': 'Infraestrutura', 'tipo_credor': 'Instituição Financeira Nacional', 'credor': 'Banco do Brasil S/A', 'moeda': 'Real', 'valor': 60000000, 'pvl_assoc_divida': 0, 'pvl_contradado_credor': 1, 'data_status': '16/09/2022'}, {'id_pleito': 62829, 'tipo_interessado': 'Município', 'interessado': 'Campos Novos', 'cod_ibge': 4203600, 'uf': 'SC', 'num_pvl': 'PVL02.009082/2022-51', 'status': 'Deferido (PVL-IF)', 'num_processo': None, 'data_protocolo': None, 'tipo_operacao': 'Operação contratual interna', 'finalidade': 'Infraestrutura', 'tipo_credor': 'Instituição Financeira Nacional', 'credor': 'Caixa Econômica Federal', 'moeda': 'Real', 'valor': 4000000, 'pvl_assoc_divida': 0, 'pvl_contradado_credor': 1, 'data_status': '25/01/2023'}, {'id_pleito': 60915, 'tipo_interessado': 'Município', 'interessado': 'Dumont', 'cod_ibge': 3514601, 'uf': 'SP', 'num_pvl': 'PV ...

# %%
df = pd.DataFrame(data['items'])

# %%
df_rio_de_janeiro = df['uf'] == 'RJ'

# %%
df_rio_de_janeiro.value_counts()
# Out:
# uf
# False    4936
# True       64
# Name: count, dtype: int64

# %%
# 2) Seu código aqui
df['status'].value_counts().head(3)
# Out:
# status
# Deferido             2761
# Deferido (PVL-IF)     924
# Arquivado             484
# Name: count, dtype: int64

# %%
# 3) Seu código aqui
df['data_status'].head()
# Out:
# 0    29/05/2023
# 1    03/08/2023
# 2    16/11/2023
# 3    13/11/2023
# 4    29/12/2021
# Name: data_status, dtype: object

# %%
# 4) Seu código aqui
df['ano'] = df['data_status'].str.extract('(\d{4})')

# %%
df['ano'].value_counts()
# Out:
# ano
# 2008    525
# 2007    322
# 2010    321
# 2023    304
# 2019    286
# 2022    276
# 2014    265
# 2006    257
# 2012    253
# 2018    251
# 2013    247
# 2021    234
# 2011    232
# 2009    217
# 2004    177
# 2020    166
# 2017    157
# 2002    137
# 2015    125
# 2016    109
# 2003     93
# 2005     46
# Name: count, dtype: int64

# %% [markdown]
# ####  2) Melhorando a interação com o API
# Observe dois URLs de consultas diferentes, por exemplo o URL utilizado em aula, e o URL feito no exercício anterior. Compare-os e observe as diferenças.
#
# 1. Faça uma função em Python que recebe como argumento o UF da consulta e o tipo de interessado (```'Estado'```ou ```Município```), e que devolve os dados da consulta no formato *DataFrame*.
# 2. Quantas solicitações para o Estado podem ser consultadas para Minas Gerais com *status* em 'Arquivado por decurso de prazo' estão registradas?
# 3. Qual é o município da Bahia com mais solicitações deferidas?
# 4. Salve um arquivo .csv com os dados de solicitações da Bahia, com interessado = 'Estado'

# %%
#1) Seu código aqui
def consulta_dados(uf, tipo_interessado):
    
    dados_filtrados = df[(df['uf'] == uf) & (df['tipo_interessado'] == tipo_interessado)]
    return dados_filtrados

# %%
# testando a função

uf_consulta = 'SP'
tipo_interessado_consulta = 'Estado'
resultado_consulta = consulta_dados(uf_consulta, tipo_interessado_consulta)
resultado_consulta
# Out:
#       id_pleito tipo_interessado interessado  cod_ibge  uf  \
# 75         5248           Estado   São Paulo        35  SP
# 194        5701           Estado   São Paulo        35  SP
# 229       67164           Estado   São Paulo        35  SP
# 938        9123           Estado   São Paulo        35  SP
# 1325       7476           Estado   São Paulo        35  SP
# 1672       9433           Estado   São Paulo        35  SP
# 1737      60909           Estado   São Paulo        35  SP
# 1848      58411           Estado   São Paulo        35  SP
# 1879       5688           Estado   São Paulo        35  SP
# 2333      10836           Estado   São Paulo        35  SP
# 2612      11458           Estado   São Paulo        35  SP
# 2863      11522           Estado   São Paulo        35  SP
# 3002      11263           Estado   São Paulo        35  SP
# 3332      10380           Estado   São Paulo        35  SP
# 3960      11493           Estado   São Paulo        35  SP
# 4326       5317           Estado   São Paulo        35  SP
# 4834      11638           Estado   São Paulo        35  SP
#
#                    num_pvl                                             status  \
# 75                    None  Encaminhado à PGFN com manifestação técnica fa...
# 194                   None  Encaminhado à PGFN com manifestação técnica fa...
# 229   PVL02.003925/2023-97                                         Em análise
# 938                   None  Encaminhado à PGFN com manifestação técnica fa...
# 1325                  None                                           Deferido
# 1672                  None                                           Deferido
# 1737  PVL02.007161/2022-28  Encaminhado à PGFN com manifestação técnica fa...
# 1848  PVL02.001041/2022-17                                           Deferido
# 1879                  None                                           Deferido
# 2333                  None  Encaminhado à PGFN com manifestação técnica fa...
# 2612                  None  Encaminhado à PGFN com manifestação técnica fa...
# 2863                  None  Encaminhado à PGFN com manifestação técnica fa...
# 3002                  None                                          Arquivado
# 3332                  None                                           Deferido
# 3960                  None                                           Deferido
# 4326                  None  Encaminhado à PGFN com manifestação técnica fa...
# 4834                  None  Encaminhado à PGFN com manifestação técnica fa...
#
#               num_processo        data_protocolo  \
#
# 1494  Operação contratual interna (com garantia da U...
# 1872  Operação contratual interna (com garantia da U...
# 2484  Operação contratual externa (com garantia da U...
# 3920  Operação contratual interna (com garantia da U...
# 4079                        Operação contratual interna
# 4926  Operação contratual interna (com garantia da U...
#
#                                              finalidade  \
# 138                                      Infraestrutura
# 923                                      Infraestrutura
# 1307                       Fortalecimento Institucional
# 1494  PEF - Programa Emergencial de Financiamento do...
# 1872                                     Infraestrutura
# 2484                                     Multissetorial
# 3920                                         Proinveste
# 4079                                               PMAE
# 4926                                     Multissetorial
#
#                                tipo_credor  \
# 138   Instituição Financeira Internacional
# 923        Instituição Financeira Nacional
# 1307  Instituição Financeira Internacional
# 1494       Instituição Financeira Nacional
# 1872       Instituição Financeira Nacional
# 2484  Instituição Financeira Internacional
# 3920       Instituição Financeira Nacional
# 4079       Instituição Financeira Nacional
# 4926       Instituição Financeira Nacional
#
#                                                  credor          moeda  \
# 138   Banco Internacional para Reconstrução e Desenv...  Dólar dos EUA
# 923   Banco Nacional de Desenvolvimento Econômico e ...           Real
# 1307            Banco Interamericano de Desenvolvimento  Dólar dos EUA
# 1494                                Banco do Brasil S/A           Real
# 1872                                Banco do Brasil S/A           Real
# 2484            Banco Interamericano de Desenvolvimento  Dólar dos EUA
# 3920  Banco Nacional de Desenvolvimento Econômico e ...           Real
# 4079  Banco Nacional de Desenvolvimento Econômico e ...           Real
# 4926                                Banco do Brasil S/A           Real
#
#              valor  pvl_assoc_divida  pvl_contradado_credor data_status  \
# 138   1.650000e+08                 0                      0  24/07/2002
# 923   3.488900e+07                 1                      0  25/06/2010
# 1307  4.000000e+07                 1                      0  10/06/2009
# 1494  1.781800e+08                 1                      0  08/10/2009
# 1872  1.500000e+09                 1                      0  12/08/2013
# 2484  1.000000e+07                 1                      0  12/03/2009
# 3920  1.326390e+09                 1                      0  02/01/2013
# 4079  7.668000e+06                 0                      0  16/03/2018
# 4926  3.653733e+09                 1                      0  03/01/2013
#
#      ano_status   ano
# 138        24/0  2002
# 923        25/0  2010
# 1307       10/0  2009
# 1494       08/1  2009
# 1872       12/0  2013
# 2484       12/0  2009
# 3920       02/0  2013
# 4079       16/0  2018
# 4926       03/0  2013

# %%
resultado_consulta['status'].value_counts()
# Out:
# status
# Encaminhado à PGFN com manifestação técnica favorável    6
# Arquivado                                                1
# Deferido                                                 1
# Arquivado por decurso de prazo                           1
# Name: count, dtype: int64

# %%
status_MG = resultado_consulta['status'] == 'Arquivado por Descurso de prazo'
status_MG.value_counts()
# Out:
# status
# False    9
# Name: count, dtype: int64

# %%
# 3) Seu código aqui
uf_consulta = 'BA'
tipo_interessado_consulta = 'Estado'
resultado_consulta = consulta_dados(uf_consulta, tipo_interessado_consulta)

# %%
resultado_consulta['status'].value_counts()
# Out:
# status
# Encaminhado à PGFN com manifestação técnica favorável    6
# Arquivado                                                1
# Deferido                                                 1
# Arquivado por decurso de prazo                           1
# Name: count, dtype: int64

# %%
deferido_data = resultado_consulta[resultado_consulta['status'] == 'Deferido']

# %%
deferido_data
# Out:
#      id_pleito tipo_interessado   interessado  cod_ibge  uf num_pvl    status  \
# 923       7280           Estado  Minas Gerais        31  MG    None  Deferido
#
#              num_processo        data_protocolo                tipo_operacao  \
# 923  17944.000537/2010-01  2010-06-24T03:00:00Z  Operação contratual interna
#
#          finalidade                      tipo_credor  \
# 923  Infraestrutura  Instituição Financeira Nacional
#
#                                                 credor moeda       valor  \
# 923  Banco Nacional de Desenvolvimento Econômico e ...  Real  34889000.0
#
#      pvl_assoc_divida  pvl_contradado_credor data_status ano_status   ano
# 923                 1                      0  25/06/2010       25/0  2010

# %%
# 4) Seu código aqui
uf_consulta = 'BA'
tipo_interessado_consulta = 'Estado'
resultado_consulta = consulta_dados(uf_consulta, tipo_interessado_consulta)
resultado_consulta.to_csv('Solicitações_Bahia.csv')
